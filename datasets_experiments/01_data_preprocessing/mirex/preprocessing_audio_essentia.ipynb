# %% [markdown]
# # Feature Extraction - package essentia
#
# In this notebook, features are extracted using the essentia package. More details about Melodia can be found in that [tutorial](https://essentia.upf.edu/essentia_python_examples.html).

# %% [markdown]
# ## Packages

# %%
# general
import numpy as np
import pandas as pd
import os
import re
from tqdm import tqdm
import warnings

# essentia
import essentia
from essentia.standard import Vibrato
import essentia.standard as es

# plots
import matplotlib.pyplot as plt
# Out:
# [   INFO   ] MusicExtractorSVM: no classifier models were configured by default

# %% [markdown]
# ## Functions

# %%
def extract_features_essentia(audio_file):
    
    features, features_frames = es.MusicExtractor(lowlevelStats=['mean', 'stdev'],
                                                  rhythmStats=['mean', 'stdev'],
                                                  tonalStats=['mean', 'stdev'])(audio_file)

    # delete non-scalar features
    feature_names = features.descriptorNames()
    features_meta = [bool(re.search('metadata', feature_names[i])) for i in range(len(feature_names))]
    feature_names = [feature_names[i] for i in range(len(feature_names)) if not features_meta[i]]
    features_tonal_key= [bool(re.search('tonal.key', feature_names[i])) for i in range(len(feature_names))]
    feature_names = [feature_names[i] for i in range(len(feature_names)) if not features_tonal_key[i]]
    features_tonal_key= [bool(re.search('tonal.chords', feature_names[i])) for i in range(len(feature_names))]
    feature_names = [feature_names[i] for i in range(len(feature_names)) if not features_tonal_key[i]]
    feature_names = [feature_name for feature_name in feature_names if np.isscalar(features[feature_name])]
    features = [features[feature_name] for feature_name in feature_names]
      
    df = pd.DataFrame(features).T
    df.columns = [feature_names[i]+'_essentia' for i in range(len(feature_names))]
    
    return df

# %%
def extract_features(file_paths):

    df = pd.DataFrame()

    for file_path in tqdm(file_paths):
        df_tmp = extract_features_essentia(file_path)
        df_tmp[['file_path']] = file_path
        df_tmp[['song_id']] = re.findall('[0-9]+', file_path)[0]
        df = pd.concat([df, df_tmp], ignore_index = True)

    return df

# %% [markdown]
# ## List of files

# %%
audio = 'mirex/dataset/Audio'
music_directory = os.listdir(audio)

# %%
file_paths = []
for file_name in music_directory:
    # Create the full file path using os.path.join()
    file_path = os.path.join(audio, file_name)
    
    # Add the file path to the list
    file_paths.append(file_path)
    
    
def extract_numeric_part(file_path):
    return [int(s) for s in os.path.basename(file_path).split('.') if s.isdigit()][0]

# Sort the file paths based on the numeric values in the file names
file_paths = sorted(file_paths, key=extract_numeric_part)
# Delete 'zone identifier':
file_paths = [file_path for file_path in file_paths if not 'Zone.Identifier' in file_path]

# %% [markdown]
# ## Extract features and save

# %%
# anoying pandas warning (concat empy df)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = extract_features(file_paths)
# Out:
#   0%|          | 0/903 [00:00<?, ?it/s]
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#   0%|          | 1/903 [00:01<23:21,  1.55s/it][   INFO   ] MusicExtractor: Read metadata
#   0%|          | 2/903 [00:04<32:15,  2.15s/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#   0%|          | 3/903 [00:05<23:44,  1.58s/it][   INFO   ] MusicExtractor: Read metadata
#   0%|          | 4/903 [00:05<19:50,  1.32s/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#   1%|          | 5/903 [00:07<19:54,  1.33s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#
/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  95%|█████████▌| 862/903 [23:27<00:59,  1.45s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▌| 863/903 [23:30<01:14,  1.87s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▌| 864/903 [23:32<01:11,  1.82s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▌| 865/903 [23:33<01:02,  1.65s/it][   INFO   ] MusicExtractor: Read metadata
#  96%|█████████▌| 866/903 [23:34<00:54,  1.46s/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▌| 867/903 [23:37<01:02,  1.74s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▌| 868/903 [23:39<01:03,  1.81s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▌| 869/903 [23:40<00:52,  1.54s/it][   INFO   ] MusicExtractor: Read metadata
#  96%|█████████▋| 870/903 [23:41<00:44,  1.36s/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  96%|█████████▋| 871/903 [23:42<00:45,  1.42s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 872/903 [23:45<00:57,  1.84s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 873/903 [23:46<00:48,  1.63s/it][   INFO   ] MusicExtractor: Read metadata
#  97%|█████████▋| 874/903 [23:47<00:42,  1.46s/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 875/903 [23:50<00:55,  2.00s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 876/903 [23:52<00:50,  1.88s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 877/903 [23:54<00:50,  1.94s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 878/903 [23:55<00:41,  1.64s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 879/903 [23:56<00:37,  1.55s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  97%|█████████▋| 880/903 [24:00<00:47,  2.07s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 881/903 [24:01<00:40,  1.83s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 882/903 [24:02<00:34,  1.63s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 883/903 [24:03<00:29,  1.48s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 884/903 [24:06<00:37,  1.98s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 885/903 [24:08<00:32,  1.81s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 887/903 [24:10<00:23,  1.44s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 888/903 [24:13<00:30,  2.04s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  98%|█████████▊| 889/903 [24:15<00:26,  1.86s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  99%|█████████▊| 890/903 [24:16<00:20,  1.58s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  99%|█████████▊| 891/903 [24:17<00:16,  1.38s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  99%|█████████▉| 892/903 [24:18<00:16,  1.48s/it][   INFO   ] MusicExtractor: Read metadata
#  99%|█████████▉| 894/903 [24:22<00:14,  1.64s/it][   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  99%|█████████▉| 895/903 [24:23<00:11,  1.50s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  99%|█████████▉| 896/903 [24:26<00:12,  1.75s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#  99%|█████████▉| 898/903 [24:29<00:07,  1.60s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# 100%|█████████▉| 899/903 [24:30<00:05,  1.48s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# 100%|█████████▉| 900/903 [24:33<00:05,  1.96s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# 100%|█████████▉| 901/903 [24:35<00:03,  1.89s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# 100%|█████████▉| 902/903 [24:36<00:01,  1.62s/it][   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# 100%|██████████| 903/903 [24:37<00:00,  1.64s/it]

# %%
df.to_csv('data/audio/preprocessed_EF.csv')
